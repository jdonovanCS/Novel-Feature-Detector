# %%
import random
import time
from copy import deepcopy
import os
import numpy as np
import collections
import matplotlib.pyplot as plt
import scikits.bootstrap as bootstrap
import warnings
warnings.filterwarnings('ignore') # Danger, Will Robinson! (not a scalable hack, and may surpress other helpful warning other than for ill-conditioned bootstrapped CI distributions)
import helper as helper
import torch

# %%
helper.run()
random_image_paths = helper.create_random_images()
trainloader = helper.load_random_images(random_image_paths)
filters = helper.get_random_filters()
activations = helper.get_activations(trainloader, filters)
for a in activations:
    print(a.shape)
# Out:
# Device: cuda
# Files already downloaded and verified
# Files already downloaded and verified
# torch.Size([3, 36, 138])
# plane  frog  frog  ship
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# (50, 4, 32, 30, 30)
# (50, 4, 64, 28, 28)
# (50, 4, 128, 26, 26)
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# (50, 4, 32, 30, 30)
# (50, 4, 64, 28, 28)
# (50, 4, 128, 26, 26)

# %%
class Model(object):
    def __init__(self):
        self.filters = None
        self.activations = None
        self.fitness = None
#         self.novelty = None

# %%
def compute_feature_novelty(activations):
    dist = {0: [], 1: [], 2: []}
    avg_dist = {0: None, 1: None, 2: None}
    for i in range(len(activations)):
        for a in activations[i]:
            for a2 in activations[i]:
                dist[i].append(np.abs(a2 - a))
        avg_dist[i] = np.mean(dist[i])
    return(sum(avg_dist.values()))

# %%
def mutate(filters):
    # select a single 3x3 filter in one of the convolutional layers and replace it with a random new filter.
    selected_layer = random.randint(0,len(filters)-1)
    selected_dims = []
    for v in list(filters[selected_layer].shape)[0:2]:
        selected_dims.append(random.randint(0,v-1))
    print('selected_layer', selected_layer, 'selected_dims', selected_dims)
    selected_filter = filters[selected_layer][selected_dims[0]][selected_dims[1]]
#   selected_filter = torch.tensor(np.random.rand(3,3), device=helper.device)
    selected_filter += np.random.rand(filters[selected_layer][selected_dims[0]][selected_dims[1]].shape)*2-1
    selected_filter = (selected_filter - np.min(selected_filter)) / (np.max(selected_filter) - np.min(selected_filter))
    filters[selected_layer][selected_dims[0]][selected_dims[1]] = selected_filter
    return filters

# %%
def evolution(generations, population_size, num_children, tournament_size, num_winners=1, evolution_type="fitness"):
    """Evolutionary Algorithm

    Args:
      generations: the number of generations the algorithm should run for.
      population_size: the number of individuals to keep in the population.
      tournament_size: the number of individuals that should participate in each
          tournament.

    Returns:
      history: a list of `Model` instances, representing all the models computed
          during the evolution experiment.
    """
    population = collections.deque()
    solutions_over_time = []
    fitness_over_time = []

    # Initialize the population with random models.
    while len(population) < population_size:
        model = Model()
        model.filters = helper.get_random_filters()
#         model.filters = mutate(model.filters)
        model.activations = helper.get_activations(trainloader, model.filters)
        model.fitness = compute_feature_novelty(model.activations)
        population.append(model)
        
    # Carry out evolution in cycles. Each cycle produces a model and removes
    # another.
    for i in range(generations):
#     while len(history) < generations:
        
        parents = []  
        while len(parents) < num_children and evolution_type != "random":
        # Sample randomly chosen models from the current population.
            tournament = []
            while len(tournament) < tournament_size:
            # Inefficient, but written this way for clarity. In the case of neural
            # nets, the efficiency of this line is irrelevant because training neural
            # nets is the rate-determining step.
                candidate = random.choice(list(population))
                tournament.append(candidate)

            # The parent is the best model in the sample.
            parents.extend(sorted(tournament, key=lambda i: i.fitness, reverse=True)[:num_winners])
        

        # Create the child model and store it.
        for parent in parents:
            child = Model()
            child.filters = mutate(parent.filters)
            child.activations = helper.get_activations(trainloader, child.filters)
            child.fitness = compute_feature_novelty(child.activations)
            population.append(child)
            
        if evolution_type == 'fitness':
            population = sorted(population, key=lambda i: i.fitness, reverse=True)[:population_size]
        
        if evolution_type == 'random':
            population = [sorted(population, key=lambda i: i.fitness, reverse=True)[0]]
            while len(population) < population_size:
                model = Model()
                model.filters = helper.get_random_filters()
                model.activations = test.get_activations(trainloader, model.filters)
                model.fitness = compute_feature_novelty(model.activations)
                population.append(model)
        
        fitness_over_time.append(1+(sorted(population, key=lambda i: i.fitness, reverse=True)[0].fitness))
        solutions_over_time.append((sorted(population, key=lambda i: i.fitness, reverse=True)[0].filters))
        
    return solutions_over_time, np.array(fitness_over_time)

# %%
num_runs = 20
run_id = 0
n_iters = 100
output_path = './'
pop_size = 50
tournament_size = 10
num_children = 50
num_winners = 5

fitness_results = {}
solution_results = {}

# %%
for run_name in ['fitness', 'random']:
    fitness_results[run_name] = np.zeros((num_runs, n_iters))
    solution_results[run_name] = np.array([[Model() for i in range(n_iters)]for j in range(num_runs)], dtype=object)
    new_output_path = os.path.join(output_path, run_name + "evolution")
    os.makedirs(os.path.join(new_output_path), exist_ok=True)
    for run_num in range(num_runs):
        start_time = time.time()
        solution_over_time, fitness_over_time = evolution(generations=n_iters, population_size=pop_size, num_children=num_children, tournament_size=tournament_size, num_winners=num_winners, evolution_type=run_name)
        fitness_results[run_name][run_num] = fitness_over_time
        solution_results[run_name][run_num] = solution_over_time
        res = [solution_results, fitness_results]
        print(run_name, run_num, time.time()-start_time, fitness_over_time[-1])
# Out:
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [20, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [14, 18]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [59, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [9, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [9, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [28, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [11, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [62, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [43, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [83, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [0, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [23, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [40, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [32, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [7, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [23, 47]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [79, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [12, 18]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [21, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [115, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [48, 33]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [5, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [66, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [3, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [17, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [48, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [123, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [31, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [103, 53]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [2, 55]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [27, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [47, 59]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [28, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [17, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [90, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [55, 16]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [35, 8]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [7, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [24, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [119, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [6, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [22, 3]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [23, 43]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [30, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [82, 48]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [12, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [13, 22]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [119, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [12, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [42, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [27, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [53, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [69, 46]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [25, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [26, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [14, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [7, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [93, 55]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [26, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [41, 58]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [28, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [65, 11]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [1, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [18, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [4, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [20, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [72, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [90, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [11, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [6, 26]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [71, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [70, 36]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [60, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [117, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [121, 59]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [41, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [100, 8]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [22, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [6, 25]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [26, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [0, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [1, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [26, 50]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [8, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [14, 3]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [55, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [55, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [24, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [30, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [25, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [60, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [21, 55]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [96, 62]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [7, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [19, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [80, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [59, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [67, 56]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [79, 41]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [25, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [75, 60]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [8, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [69, 60]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [28, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [14, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [27, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [51, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [12, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [5, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [29, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [18, 22]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [108, 52]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [14, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [15, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [26, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [25, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [11, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [99, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [12, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [49, 8]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [25, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [118, 60]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [20, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [36, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [65, 49]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [42, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [50, 54]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [28, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [9, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [19, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [111, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [5, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [8, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [24, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [1, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [35, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [38, 25]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [49, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [25, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [3, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [101, 57]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [36, 18]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [49, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [16, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [26, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [44, 49]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [31, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [16, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [14, 49]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [44, 22]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [84, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [3, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [12, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [16, 25]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [18, 3]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [16, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [19, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [22, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 30]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [26, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [11, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [14, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [19, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [73, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [48, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [39, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [56, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [63, 42]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [10, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [47, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [62, 37]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [6, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [73, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [122, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [20, 3]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [29, 4]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [68, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [31, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [15, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [20, 16]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [39, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [12, 46]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [39, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [38, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [41, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [64, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [20, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [8, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [65, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [12, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [24, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [18, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [59, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [34, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [10, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [81, 28]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [47, 40]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [16, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [16, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [21, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [13, 25]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [58, 11]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [58, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [17, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [60, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [73, 49]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [18, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [10, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [30, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [63, 25]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [105, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [28, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [3, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [8, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [36, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [23, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [23, 45]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [16, 51]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [37, 55]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [8, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [95, 34]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [18, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [29, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [30, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [8, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [28, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [49, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [45, 45]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [18, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [102, 27]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [6, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [27, 16]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [4, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [40, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [27, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [16, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [17, 62]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [116, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [9, 36]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [21, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [0, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [42, 22]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [32, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [49, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [15, 24]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [36, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [34, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [17, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [29, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [104, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [59, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [50, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [22, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [6, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [113, 52]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 6]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [6, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [22, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [26, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [55, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [22, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [21, 61]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [32, 9]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [24, 20]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [32, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [121, 58]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [42, 55]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [127, 16]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [8, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [10, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [1, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [16, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [36, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [23, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [15, 44]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [17, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [61, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [11, 5]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [42, 62]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [6, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [95, 39]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [78, 59]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [18, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [87, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [28, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [24, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [6, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [28, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [14, 26]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [57, 54]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [11, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [42, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [3, 36]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [121, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [9, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [3, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [13, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [2, 21]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [49, 15]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [72, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [4, 17]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [33, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 10]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [58, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [29, 54]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [77, 19]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [61, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [15, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [29, 26]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [53, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [34, 37]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [18, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [42, 60]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [35, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [6, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [48, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [16, 35]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [22, 23]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [58, 31]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [23, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [50, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [38, 9]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [58, 59]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [32, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [83, 57]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [5, 13]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [23, 7]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [27, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [25, 30]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [9, 2]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [9, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [31, 14]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [2, 1]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [3, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [24, 29]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [29, 50]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [11, 53]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [63, 18]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [18, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 2 selected_dims [79, 12]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 0 selected_dims [1, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [0, 0]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# selected_layer 1 selected_dims [60, 3]
# torch.Size([32, 3, 3, 3])
# torch.Size([64, 32, 3, 3])
# torch.Size([128, 64, 3, 3])
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14656/3839617069.py in <module>
#       6     for run_num in range(num_runs):
#       7         start_time = time.time()
# ----> 8         solution_over_time, fitness_over_time = evolution(generations=n_iters, population_size=pop_size, num_children=num_children, tournament_size=tournament_size, num_winners=num_winners, evolution_type=run_name)
#       9         fitness_results[run_name][run_num] = fitness_over_time
#      10         solution_results[run_name][run_num] = solution_over_time
#
# ~\AppData\Local\Temp/ipykernel_14656/2287514475.py in evolution(generations, population_size, num_children, tournament_size, num_winners, evolution_type)
#      49             child = Model()
#      50             child.filters = mutate(parent.filters)
# ---> 51             child.activations = test.get_activations(trainloader, child.filters)
#      52             child.fitness = compute_feature_novelty(child.activations)
#      53             population.append(child)
#
# ~\Learning\UVM\Research Projects\Novel-Feature-Detector\testcopy.py in get_activations(trainloader, filters)
#     132
#     133     activations_dict = {"conv1": [], "conv2": [], "conv3": []}
# --> 134     for i, data in enumerate(trainloader, 0):
#     135         inputs, labels = data
#     136         inputs = np.transpose(inputs, (0, 3, 2, 1)).float()
#
# ~\anaconda3\envs\EC\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\envs\EC\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#    1201             else:
#    1202                 del self._task_info[idx]
# -> 1203                 return self._process_data(data)
#    1204
#    1205     def _try_put_index(self):
#
# ~\anaconda3\envs\EC\lib\site-packages\torch\utils\data\dataloader.py in _process_data(self, data)
#    1227         self._try_put_index()
#    1228         if isinstance(data, ExceptionWrapper):
# -> 1229             data.reraise()
#    1230         return data
#    1231
#
# ~\anaconda3\envs\EC\lib\site-packages\torch\_utils.py in reraise(self)
#     432             # instantiate since we don't know how to
#     433             raise RuntimeError(msg) from None
# --> 434         raise exception
#     435
#     436
#
# error: Caught error in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "C:\Users\Jordan\anaconda3\envs\EC\lib\site-packages\torch\utils\data\_utils\worker.py", line 287, in _worker_loop
#     data = fetcher.fetch(index)
#   File "C:\Users\Jordan\anaconda3\envs\EC\lib\site-packages\torch\utils\data\_utils\fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\Jordan\anaconda3\envs\EC\lib\site-packages\torch\utils\data\_utils\fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\Jordan\Learning\UVM\Research Projects\Novel-Feature-Detector\randomdataset.py", line 14, in __getitem__
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# cv2.error: OpenCV(4.5.4) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
